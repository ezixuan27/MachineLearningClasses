# %%
#!/usr/bin/env python

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import expon

# %% [markdown]
# Parameters

# %%
μ = 0.5  # Mean of the exponential distribution
sample_size = 4000  # Number of samples

# %% [markdown]
# Generate samples from the exponential distribution

# %%
samples = np.random.exponential(scale=μ, size=sample_size)

# %% [markdown]
# Create a histogram of the samples

# %%
plt.hist(samples, bins=50, density=True, color='blue', alpha=0.7, label='Histogram')
# Out:
# (array([1.86022029, 1.51973354, 1.17094224, 1.17094224, 0.883051  ,
#         0.71972809, 0.58685521, 0.5148824 , 0.44290959, 0.37647315,
#         0.30450035, 0.30450035, 0.17716384, 0.1660911 , 0.13287288,
#         0.16055473, 0.06920462, 0.09411829, 0.08858192, 0.05259551,
#         0.05259551, 0.02768185, 0.02214548, 0.03321822, 0.02491366,
#         0.01660911, 0.01384092, 0.01937729, 0.01107274, 0.00276818,
#         0.00276818, 0.00276818, 0.        , 0.00830455, 0.01107274,
#         0.00553637, 0.00830455, 0.        , 0.        , 0.        ,
#         0.        , 0.00276818, 0.        , 0.00553637, 0.00276818,
#         0.        , 0.        , 0.        , 0.        , 0.00276818]),
#  array([2.04457261e-05, 9.03323302e-02, 1.80644215e-01, 2.70956099e-01,
#         3.61267984e-01, 4.51579868e-01, 5.41891752e-01, 6.32203637e-01,
#         7.22515521e-01, 8.12827406e-01, 9.03139290e-01, 9.93451175e-01,
#         1.08376306e+00, 1.17407494e+00, 1.26438683e+00, 1.35469871e+00,
#         1.44501060e+00, 1.53532248e+00, 1.62563437e+00, 1.71594625e+00,
#         1.80625813e+00, 1.89657002e+00, 1.98688190e+00, 2.07719379e+00,
#         2.16750567e+00, 2.25781756e+00, 2.34812944e+00, 2.43844133e+00,
#         2.52875321e+00, 2.61906509e+00, 2.70937698e+00, 2.79968886e+00,
#         2.89000075e+00, 2.98031263e+00, 3.07062452e+00, 3.16093640e+00,
#         3.25124829e+00, 3.34156017e+00, 3.43187206e+00, 3.52218394e+00,
#         3.61249582e+00, 3.70280771e+00, 3.79311959e+00, 3.88343148e+00,
#         3.97374336e+00, 4.06405525e+00, 4.15436713e+00, 4.24467902e+00,
#         4.33499090e+00, 4.42530278e+00, 4.51561467e+00]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# Overlay the theoretical exponential distribution

# %%
x = np.linspace(0, max(samples), 1000)
pdf = expon.pdf(x, scale=μ)  # Probability density function
plt.plot(x, pdf, 'r-', lw=2, label='Exponential PDF')

# %% [markdown]
# Add labels and title

# %%
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Exponential Distribution (μ=0.5)')
plt.legend()

# %% [markdown]
# Use tight_layout to adjust spacing

# %%
plt.tight_layout()

# %% [markdown]
# Show the plot

# %%
plt.show()
